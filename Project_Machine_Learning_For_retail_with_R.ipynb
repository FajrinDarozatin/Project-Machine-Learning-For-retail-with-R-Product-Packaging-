# %% [markdown]
# <a href="https://colab.research.google.com/github/FajrinDarozatin/Project-Machine-Learning-For-retail-with-R-Product-Packaging-/blob/main/Project_Machine_Learning_For_retail_with_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install r-base
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# r-base is already the newest version (4.4.1-3.2204.0).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !pip install rpy2

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("arules")
# library(arules)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/arules_1.7-8.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1873243 bytes (1.8 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# Sel Python untuk membaca dan menampilkan file dalam format tabel
import pandas as pd

# %%
# %%R
# library(arules)
# transaksi_tabular <- read.transactions(file="https://storage.googleapis.com/dqlab-dataset/transaksi_dqlab_retail.tsv", format="single", sep="\t", cols=c(1,2), skip=1)
# write(transaksi_tabular, file="test_project_retail_1.txt", sep=",")

# %% [markdown]
# Menampilkan Top 10  dari dataset transaksi

# %%
# %%R
# library(arules)
# transaksi <- read.transactions(file="https://storage.googleapis.com/dqlab-dataset/transaksi_dqlab_retail.tsv", format="single", sep="\t", cols=c(1,2), skip=1)

# %%
# %%R
# data_item <- sort(itemFrequency(transaksi,type="absolute"), decreasing=TRUE)[1:10]
# data_item <- data.frame("Nama.Produk"=names(data_item), "Jumlah"=data_item, row.names=NULL)
# write.csv(data_item, file="top10_item_retail.txt")

# %%
# Membaca file CSV
data_item_df = pd.read_csv('top10_item_retail.txt')

# %%
# Menampilkan tabel
data_item_df
# Out:
#    Unnamed: 0                Nama.Produk  Jumlah
# 0           1               Shampo Biasa    2075
# 1           2              Serum Vitamin    1685
# 2           3          Baju Batik Wanita    1312
# 3           4          Baju Kemeja Putih    1255
# 4           5       Celana Jogger Casual    1136
# 5           6                Cover Koper    1086
# 6           7         Sepatu Sandal Anak    1062
# 7           8  Tali Pinggang Gesper Pria    1003
# 8           9        Sepatu Sport merk Z     888
# 9          10               Wedges Hitam     849

# %% [markdown]
# Menampilkan Bottom 10 dari dataset transaksi

# %%
# %%R
# library(arules)
# transaksi <- read.transactions(file="transaksi_dqlab_retail.tsv",format="single",sep="\t",cols=c(1,2),skip=1)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(file, "r") : cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(file, "r") :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'transaksi_dqlab_retail.tsv': No such file or directory
# Error in file(file, "r") : cannot open the connection

# %%
# %%R
# data_item <- itemFrequency(transaksi,type="absolute")
# data_item <- sort(data_item, decreasing = FALSE)
# data_item <- data_item[1:10]
# data_item <- data.frame("Nama.Produk"=names(data_item),"Jumlah"=data_item,row.names=NULL)
# write.csv(data_item,file="bottom10_item_retail.txt")

# %%
# Membaca file CSV
data_item_df = pd.read_csv('bottom10_item_retail.txt')

# %%
# Menampilkan tabel
data_item_df
# Out:
#    Unnamed: 0                 Nama.Produk  Jumlah
# 0           1     Celana Jeans Sobek Pria       9
# 1           2                Tas Kosmetik      11
# 2           3                Stripe Pants      19
# 3           4                    Pelembab      24
# 4           5      Tali Ban Ikat Pinggang      27
# 5           6  Baju Renang Pria Anak-anak      32
# 6           7                    Hair Dye      46
# 7           8          Atasan Baju Belang      56
# 8           9  Tas Sekolah Anak Perempuan      71
# 9          10               Dompet Unisex      75

# %% [markdown]
# Mendapatkan Daftar 10 paket kombinasi produk yang paling "menarik"

# %%
# %%R
# library(arules)
# transaksi_tabular <- read.transactions(file="transaksi_dqlab_retail.tsv", format="single", sep="\t", cols=c(1,2), skip=1)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(file, "r") : cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning message:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(file, "r") :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  cannot open file 'transaksi_dqlab_retail.tsv': No such file or directory
# Error in file(file, "r") : cannot open the connection

# %%
# %%R
# mba <- apriori(transaksi_tabular, parameter=list(supp = 10/nrow(transaksi_tabular), minlen = 2, maxlen = 3, confidence = 0.5))
# data <- sort(mba, by="lift", decreasing="TRUE")
# data <- data[1:10]
# write(data, file="kombinasi_retail.txt")
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime     support minlen
#         0.5    0.1    1 none FALSE            TRUE       5 0.002898551      2
#  maxlen target  ext
#       3  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 10
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[69 item(s), 3450 transaction(s)] done [0.01s].
# sorting and recoding items ... [68 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.01s].
# writing ... [4637 rule(s)] done [0.01s].
# creating S4 object  ... done [0.01s].

# %%
# Membaca file CSV
data_item_df = pd.read_csv('kombinasi_retail.txt')

# %%
# Menampilkan tabel
data_item_df
# Out:
#                                  rules "support" "confidence" "coverage" "lift" "count"
# 797 "{Tas Makeup                  Tas Pinggang Wanita} => {Baju Renang Anak Pere...
# 807 "{Tas Makeup                  Tas Travel} => {Baju Renang Anak Perempuan}" 0...
# 802 "{Tas Makeup                  Tas Ransel Mini} => {Baju Renang Anak Perempua...
# 649 "{Sunblock Cream              Tas Pinggang Wanita} => {Kuas Makeup }" 0.0162...
# 796 "{Baju Renang Anak Perempuan  Tas Pinggang Wanita} => {Tas Makeup}" 0.010434...
# 801 "{Baju Renang Anak Perempuan  Tas Ransel Mini} => {Tas Makeup}" 0.0113043478...
# 791 "{Baju Renang Anak Perempuan  Celana Pendek Green/Hijau} => {Tas Makeup}" 0....
# 799 "{Tas Makeup                  Tas Waist Bag} => {Baju Renang Anak Perempuan}...
# 792 "{Celana Pendek Green/Hijau   Tas Makeup} => {Baju Renang Anak Perempuan}" 0...
# 656 "{Dompet Flip Cover           Sunblock Cream} => {Kuas Makeup }" 0.016231884...

# %% [markdown]
# Mencari Paket Produk yang bisa dipasangkan dengan Item Slow-Moving

# %%
# %%R
# library(arules)
# nama_file <- "transaksi_dqlab_retail.tsv"
# transaksi_tabular <- read.transactions(file=nama_file, format="single", sep="\t", cols=c(1,2), skip=1)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in file(file, "r") : cannot open the connection
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning messages:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 1:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In apriori(transaksi_tabular, parameter = list(supp = 10/nrow(transaksi_tabular),  :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  Mining stopped (maxlen reached). Only patterns up to a length of 3 returned!
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 2:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In file(file, "r") :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# ...

# %%
# %%R
# jumlah_transaksi<-length(transaksi_tabular)
# jumlah_kemunculan_minimal <- 10
# apriori_rules <- apriori(transaksi_tabular,parameter=list(supp=jumlah_kemunculan_minimal/jumlah_transaksi,conf=0.1, minlen=2, maxlen=3))
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime     support minlen
#         0.1    0.1    1 none FALSE            TRUE       5 0.002898551      2
#  maxlen target  ext
#       3  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 10
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[69 item(s), 3450 transaction(s)] done [0.01s].
# sorting and recoding items ... [68 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 done [0.01s].
# writing ... [39832 rule(s)] done [0.07s].
# creating S4 object  ... done [0.02s].

# %%
#FILTER
# %%R
apriori_rules1 <- subset(apriori_rules, lift > 1 & rhs %in% "Tas Makeup")
apriori_rules1 <- sort(apriori_rules1, by='lift', decreasing = T)[1:3]
apriori_rules2 <- subset(apriori_rules, lift > 1 & rhs %in% "Baju Renang Pria Anak-anak")
apriori_rules2 <- sort(apriori_rules2, by='lift', decreasing = T)[1:3]
apriori_rules <- c(apriori_rules1, apriori_rules2)
inspect(apriori_rules)
write(apriori_rules,file="kombinasi_retail_slow_moving.txt")
# Out:
#     lhs                              rhs                              support confidence   coverage     lift count
# [1] {Baju Renang Anak Perempuan,
#      Tas Pinggang Wanita}         => {Tas Makeup}                 0.010434783  0.8000000 0.01304348 19.57447    36
# [2] {Baju Renang Anak Perempuan,
#      Tas Ransel Mini}             => {Tas Makeup}                 0.011304348  0.7959184 0.01420290 19.47460    39
# [3] {Baju Renang Anak Perempuan,
#      Celana Pendek Green/Hijau}   => {Tas Makeup}                 0.010144928  0.7777778 0.01304348 19.03073    35
# [4] {Gembok Koper,
#      Tas Waist Bag}               => {Baju Renang Pria Anak-anak} 0.004057971  0.2745098 0.01478261 29.59559    14
# [5] {Flat Shoes Ballerina,
#      Gembok Koper}                => {Baju Renang Pria Anak-anak} 0.004057971  0.1866667 0.02173913 20.12500    14
# [6] {Celana Jeans Sobek Wanita,
# ...

# %%
# Membaca file CSV
data_item_df = pd.read_csv('kombinasi_retail_slow_moving.txt')

# Menampilkan tabel
data_item_df
# Out:
#                                   rules "support" "confidence" "coverage" "lift" "count"
# 3798 "{Baju Renang Anak Perempuan  Tas Pinggang Wanita} => {Tas Makeup}" 0.010434...
# 3804 "{Baju Renang Anak Perempuan  Tas Ransel Mini} => {Tas Makeup}" 0.0113043478...
# 3792 "{Baju Renang Anak Perempuan  Celana Pendek Green/Hijau} => {Tas Makeup}" 0....
# 2290 "{Gembok Koper                Tas Waist Bag} => {Baju Renang Pria Anak-anak}...
# 2293 "{Flat Shoes Ballerina        Gembok Koper} => {Baju Renang Pria Anak-anak}"...
# 2298 "{Celana Jeans Sobek Wanita   Jeans Jumbo} => {Baju Renang Pria Anak-anak}" ...
